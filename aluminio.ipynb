# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Tamb=110
guia = np.array([['1i','2s','2s','1d','amb','amb','amb','amb','amb','amb','amb','amb','1i','2s','2s','1d'],
['2i','6','6','2d','amb','amb','amb','amb','amb','amb','amb','amb','2i','6','6','2d'],
['2i','6','6','2d','amb','amb','amb','amb','amb','amb','amb','amb','2i','6','6','2d'],
['2i','6','6','2d','amb','amb','amb','amb','amb','amb','amb','amb','2i','6','6','2d'],
['2i','6','6','2d','amb','amb','amb','amb','amb','amb','amb','amb','2i','6','6','2d'],
['2i','6','6','2d','amb','amb','amb','amb','amb','amb','amb','amb','2i','6','6','2d'],
['2i','6','6','2d','amb','amb','amb','amb','amb','amb','amb','amb','2i','6','6','2d'],
['2i','6','6','3da','2s','2s','2s','2s','2s','2s','2s','2s','3ia','6','6','2d'],
['2i','6','6','6','6','6','6','6','6','6','6','6','6','6','6','2d'],
['2i','6','6','6','6','6','6','6','6','6','6','6','6','6','6','2d'],
['2i','6','6','3db','2b','2b','3ib','6','6','3db','2b','2b','3ib','6','6','2d'],
['2i','6','6','2d','amb','amb','2i','6','6','2d','amb','amb','2i','6','6','2d'],
['2i','6','6','2d','amb','amb','2i','6','6','2d','amb','amb','2i','6','6','2d'],
['2i','6','6','2d','amb','amb','2i','6','6','2d','amb','amb','2i','6','6','2d'],
['2i','6','6','2d','amb','amb','2i','6','6','2d','amb','amb','2i','6','6','2d'],
['2i','6','6','2d','amb','amb','2i','6','6','2d','amb','amb','2i','6','6','2d'],
['2i','6','6','2d','amb','amb','2i','6','6','2d','amb','amb','2i','6','6','2d'],
['4i','5','5','4d','amb','amb','4i','5','5','4d','amb','amb','4i','5','5','4d']])

# %%
tipos = ['1i','1d','2s','2i','2d','2b','3da','3ia','3db','3ib','4i','4d','5','6','amb']
ecs = ['m1[i][j]*(1-4*tao-(4*tao*h*dx)/k-(2*tao*h*dx**2)/(k*e))+(2*tao*h*dx*Tamb)/k*(2+dx/e)+2*tao*(m1[i][j+1]+m1[i+1][j])',
'm1[i][j]*(1-4*tao-(4*tao*h*dx)/k-(2*tao*h*dx**2)/(k*e))+(2*tao*h*dx*Tamb)/k*(2+dx/e)+2*tao*(m1[i][j-1]+m1[i+1][j])',
'Tamb*2*tao*h*dx/k*(1+dx/e)+m1[i][j]*(1-4*tao-2*tao*h*dx/k-2*tao*h*dx**2/(e*k))+tao*(m1[i][j+1]+m1[i][j-1]+2*m1[i+1][j])',
'Tamb*2*tao*h*dx/k*(1+dx/e)+m1[i][j]*(1-4*tao-2*tao*h*dx/k-2*tao*h*dx**2/(e*k))+tao*(m1[i+1][j]+m1[i-1][j]+2*m1[i][j+1])',
'Tamb*2*tao*h*dx/k*(1+dx/e)+m1[i][j]*(1-4*tao-2*tao*h*dx/k-2*tao*h*dx**2/(e*k))+tao*(m1[i+1][j]+m1[i-1][j]+2*m1[i][j-1])',
'Tamb*2*tao*h*dx/k*(1+dx/e)+m1[i][j]*(1-4*tao-2*tao*h*dx/k-2*tao*h*dx**2/(e*k))+tao*(m1[i][j+1]+m1[i][j-1]+2*m1[i-1][j])',
'Tamb*2*tao*h*dx/k*(2/3+dx/e)+m1[i][j]*(1-4*tao-4*tao*h*dx/(3*k)-2*tao*h*dx**2/(e*k))+2*tao/3*(2*m1[i+1][j]+2*m1[i][j-1]+m1[i-1][j]+m1[i][j+1])',
'Tamb*2*tao*h*dx/k*(2/3+dx/e)+m1[i][j]*(1-4*tao-4*tao*h*dx/(3*k)-2*tao*h*dx**2/(e*k))+2*tao/3*(2*m1[i+1][j]+m1[i][j-1]+m1[i-1][j]+2*m1[i][j+1])',
'Tamb*2*tao*h*dx/k*(2/3+dx/e)+m1[i][j]*(1-4*tao-4*tao*h*dx/(3*k)-2*tao*h*dx**2/(e*k))+2*tao/3*(m1[i+1][j]+2*m1[i][j-1]+2*m1[i-1][j]+m1[i][j+1])',
'Tamb*2*tao*h*dx/k*(2/3+dx/e)+m1[i][j]*(1-4*tao-4*tao*h*dx/(3*k)-2*tao*h*dx**2/(e*k))+2*tao/3*(m1[i+1][j]+m1[i][j-1]+2*m1[i-1][j]+2*m1[i][j+1])',
'Tamb*2*tao*h*dx/k*(1+dx/e)+m1[i][j]*(1-4*tao-2*tao*h*dx/k-2*tao*h*dx**2/(e*k))+2*tao*(m1[i][j+1]+m1[i-1][j])',
'Tamb*2*tao*h*dx/k*(1+dx/e)+m1[i][j]*(1-4*tao-2*tao*h*dx/k-2*tao*h*dx**2/(e*k))+2*tao*(m1[i][j-1]+m1[i-1][j])',
'Tamb*2*tao*h*dx**2/(e*k)+m1[i][j]*(1-4*tao-2*tao*h*dx**2/(e*k))+tao*(m1[i][j+1]+m1[i][j-1]+2*m1[i-1][j])',
'Tamb*2*tao*h*dx**2/(e*k)+m1[i][j]*(1-4*tao-2*tao*h*dx**2/(e*k))+tao*(m1[i+1][j]+m1[i-1][j]+m1[i][j+1]+m1[i][j-1])',
'Tamb']

# %% [markdown]
# Segunda parte para aluminio

# %%
dt = 0.025
tao = 0.2110639
Cp = 900 
ro = 2699
h=200
k=210
dx=3.2e-3
e=1e-3

# %%
m1=np.array([[15,15,15,15,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,Tamb,15,15,15,15],
[15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15],
[15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15],
[15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15],
[15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15],
[15,15,15,15,Tamb,Tamb,15,15,15,15,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,15,15,15,15,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,15,15,15,15,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,15,15,15,15,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,15,15,15,15,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,15,15,15,15,Tamb,Tamb,15,15,15,15],
[15,15,15,15,Tamb,Tamb,15,15,15,15,Tamb,Tamb,15,15,15,15]])
tam = (18,16)
m2=np.zeros(tam)
t=0

# %%
sns.heatmap(m1,annot=True,fmt=".1f",annot_kws={"size":6}, yticklabels=False,xticklabels=False)
# Out:
# <Axes: >

# %%
tiempo = []
Ts=[]
while m2[17][0]<100:
#for w in range(4000):
    for i in range(len(guia)):
        for j in range(len(guia[i])):
            m2[i][j]=eval(ecs[tipos.index(guia[i][j])])
    m1=m2.copy()
    t+=dt
    
    tiempo.append(t)
    Ts.append(m2[17][0])
sns.heatmap(m2,annot=True,fmt=".1f",annot_kws={"size":6}, yticklabels=False,xticklabels=False)
# Out:
# <Axes: >

# %%
while m2[17][0]<109.99:
    for i in range(len(guia)):
        for j in range(len(guia[i])):
            m2[i][j]=eval(ecs[tipos.index(guia[i][j])])
    m1=m2.copy()
    t+=0.019
    
    tiempo.append(t)
    Ts.append(m2[17][0])

#print('Tiempo para 100°C', tiempo[Ts.index(100)])
print('Tiempo total', tiempo[len(tiempo)-1])

sns.heatmap(m2,annot=True,fmt=".1f",annot_kws={"size":6}, yticklabels=False,xticklabels=False)
# Out:
# Tiempo total 41.29899999999794
# <Axes: >

# %%
for i in range(len(tiempo)):
    if Ts[i]>=100:
        print('Tiempo para los 100°C: ', tiempo[i])
        break
# Out:
# Tiempo para los 100°C:  12.400000000000109

# %%
plt.plot(tiempo,Ts)
plt.xlabel('Tiempo [s]')
plt.ylabel('Temperatura [°C]')
plt.show()
